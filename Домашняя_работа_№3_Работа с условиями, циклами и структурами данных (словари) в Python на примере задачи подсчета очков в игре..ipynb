# %% [markdown]
# **Навигация по уроку**
#
# 1. [Условия и циклы.  Списки, словари, кортежи, множества](https://colab.research.google.com/drive/1DFtKZbd2GjOsVRNViq_p9gCo9kNDTDpD#scrollTo=UWRmGWmyGHbN)
# 2. [Практика кода](https://colab.research.google.com/drive/1FlsYqi3sK_GWY6gM_vWJL8qgJOu1x0Ac)
# 3. Домашняя работа

# %% [markdown]
# Для прохождения урока необходимо решить минимум 2 задачи. Желаем удачи!

# %% [markdown]
# ## Задача 1. Собачий возраст.

# %% [markdown]
# **Условие.** Считается, что один год, прожитый собакой, эквивалентен семи человеческим годам. При этом зачастую не учитывается, что собаки становятся
# абсолютно взрослыми уже к двум годам. Таким образом, многие предпочитают каждый из первых двух лет жизни собаки приравнивать к 10,5 года человеческой жизни, а все последующие – к четырем.
# Напишите программу, которая будет переводить человеческий возраст в  собачий с  учетом указанной выше логики. Убедитесь, что программа
# корректно работает при пересчете возраста собаки меньше и больше двух лет.

# %%
#Решение задачи
#Объявим переменную для хранения значения вводимого пользователем
age = float(input("Укажите количество лет вашей собаки: "))

if age <= 2:
    print("Вашей собаке:",age * 10.5,"при переводе в человеческий возраст.")
else:
    print("Вашей собаке:",21 + (age - 2) * 4,"при переводе в человеческий возраст.")

#Вопрос. Правильно ли будет упрощать код, где это возможно
#или стоит каждую операцию выносить в переменную?
#Например 21 + (age - 2) * 4 правильнее ли эту часть кода выносить в отдельную переменную?
# Out:
# Укажите количество лет вашей собаки: 3
# Вашей собаке: 25.0 при переводе в человеческий возраст.

# %% [markdown]
# ## Задача 2. Какого цвета клетка?

# %% [markdown]
# **Условие.** Клетки на шахматной доске идентифицируются буквой и цифрой. Буква определяет положение клетки по горизонтали, а цифра – по вертикали, как показано на рисунке.
#
# ![image.png](data:image/png;base64,...)
#
# Ваша программа должна запрашивать у пользователя координаты клетки. Используйте условное выражение для определения того, с какой клетки – белой или черной – начинается столбец. Затем при помощи обычной арифметики необходимо определить цвет конкретной клетки. Например, если пользователь ввел a1, программа должна определить, что клетка
# с этими координатами черная. Если d5 – белая.

# %%
#Создаём список с буквами шахматной доски
list_letter= ['0','a','b','c','d','e','f','g','h']

#Создадим переменную для ввода координаты клетки
enter_value = input("Введите координаты клетки. Пример(1f):")

#Создадим цикл для перебора элементов списка с буквами
for i in range(len(list_letter)):
    #Если первый символ вводимого значения равен одному из символов списка
    if enter_value[1] == list_letter[i]:
        if (int(enter_value[0]) + (int(list_letter.index(enter_value[1])))-1) % 2 == 0:
            print("Клетка с этими координатами белая.")
            break
        else:
            print("Клетка с этими координатами чёрная.")
            break
# Out:
# Введите координаты клетки. Пример(1f):4g
# Клетка с этими координатами белая.

# %% [markdown]
# ## Задача 3. Игра Fizz-Buzz.

# %% [markdown]
# **Условие.** Fizz-Buzz  – это известная игра, помогающая детям освоить в  игровой форме правила деления. Участники садятся в круг, чтобы игра теоретически могла продолжаться бесконечно. Первый игрок говорит «Один» и передает ход тому, кто слева. Каждый следующий игрок должен мысленно прибавить к предыдущему числу единицу и произнести либо его, либо одно из ключевых слов: Fizz, если число без остатка делится на три, или Buzz, если на пять. Если соблюдаются оба этих условия, он произносит Fizz-Buzz. Игрок, не сумевший сказать правильное слово, выбывает из игры. Последний оставшийся игрок признается победителем.
# Разработайте программу, реализующую алгоритм игры Fizz-Buzz применительно к  первым 100 числам. Каждый следующий ответ должен отображаться на новой строке.

# %%
for i in range(1,101):
    if i % 3 == 0 and i % 5 == 0:
        print("Fizz-Buzz, число:",i)
    elif i % 5 == 0:
        print("Buzz, число:",i)
    elif i % 3 == 0:
        print("Fizz, число: ",i)
    else:
        print("Число, которое не делится на 3 и на 5 без остатка:",i)
# Out:
# Число, которое не делится на 3 и на 5 без остатка: 1
# Число, которое не делится на 3 и на 5 без остатка: 2
# Fizz, число:  3
# Число, которое не делится на 3 и на 5 без остатка: 4
# Buzz, число: 5
# Fizz, число:  6
# Число, которое не делится на 3 и на 5 без остатка: 7
# Число, которое не делится на 3 и на 5 без остатка: 8
# Fizz, число:  9
# Buzz, число: 10
# Число, которое не делится на 3 и на 5 без остатка: 11
# Fizz, число:  12
# Число, которое не делится на 3 и на 5 без остатка: 13
# Число, которое не делится на 3 и на 5 без остатка: 14
# Fizz-Buzz, число: 15
# Число, которое не делится на 3 и на 5 без остатка: 16
# Число, которое не делится на 3 и на 5 без остатка: 17
# Fizz, число:  18
# Число, которое не делится на 3 и на 5 без остатка: 19
# Buzz, число: 20
# Fizz, число:  21
# Число, которое не делится на 3 и на 5 без остатка: 22
# Число, которое не делится на 3 и на 5 без остатка: 23
# Fizz, число:  24
# Buzz, число: 25
# Число, которое не делится на 3 и на 5 без остатка: 26
# Fizz, число:  27
# Число, которое не делится на 3 и на 5 без остатка: 28
# Число, которое не делится на 3 и на 5 без остатка: 29
# Fizz-Buzz, число: 30
# Число, которое не делится на 3 и на 5 без остатка: 31
# Число, которое не делится на 3 и на 5 без остатка: 32
# Fizz, число:  33
# Число, которое не делится на 3 и на 5 без остатка: 34
# Buzz, число: 35
# Fizz, число:  36
# Число, которое не делится на 3 и на 5 без остатка: 37
# Число, которое не делится на 3 и на 5 без остатка: 38
# Fizz, число:  39
# Buzz, число: 40
# Число, которое не делится на 3 и на 5 без остатка: 41
# Fizz, число:  42
# Число, которое не делится на 3 и на 5 без остатка: 43
# Число, которое не делится на 3 и на 5 без остатка: 44
# Fizz-Buzz, число: 45
# Число, которое не делится на 3 и на 5 без остатка: 46
# Число, которое не делится на 3 и на 5 без остатка: 47
# Fizz, число:  48
# Число, которое не делится на 3 и на 5 без остатка: 49
# Buzz, число: 50
# Fizz, число:  51
# Число, которое не делится на 3 и на 5 без остатка: 52
# Число, которое не делится на 3 и на 5 без остатка: 53
# Fizz, число:  54
# Buzz, число: 55
# Число, которое не делится на 3 и на 5 без остатка: 56
# Fizz, число:  57
# Число, которое не делится на 3 и на 5 без остатка: 58
# Число, которое не делится на 3 и на 5 без остатка: 59
# Fizz-Buzz, число: 60
# Число, которое не делится на 3 и на 5 без остатка: 61
# Число, которое не делится на 3 и на 5 без остатка: 62
# Fizz, число:  63
# Число, которое не делится на 3 и на 5 без остатка: 64
# Buzz, число: 65
# Fizz, число:  66
# Число, которое не делится на 3 и на 5 без остатка: 67
# Число, которое не делится на 3 и на 5 без остатка: 68
# Fizz, число:  69
# Buzz, число: 70
# Число, которое не делится на 3 и на 5 без остатка: 71
# Fizz, число:  72
# Число, которое не делится на 3 и на 5 без остатка: 73
# Число, которое не делится на 3 и на 5 без остатка: 74
# Fizz-Buzz, число: 75
# Число, которое не делится на 3 и на 5 без остатка: 76
# Число, которое не делится на 3 и на 5 без остатка: 77
# Fizz, число:  78
# Число, которое не делится на 3 и на 5 без остатка: 79
# Buzz, число: 80
# Fizz, число:  81
# Число, которое не делится на 3 и на 5 без остатка: 82
# Число, которое не делится на 3 и на 5 без остатка: 83
# Fizz, число:  84
# Buzz, число: 85
# Число, которое не делится на 3 и на 5 без остатка: 86
# Fizz, число:  87
# Число, которое не делится на 3 и на 5 без остатка: 88
# Число, которое не делится на 3 и на 5 без остатка: 89
# Fizz-Buzz, число: 90
# Число, которое не делится на 3 и на 5 без остатка: 91
# Число, которое не делится на 3 и на 5 без остатка: 92
# Fizz, число:  93
# Число, которое не делится на 3 и на 5 без остатка: 94
# Buzz, число: 95
# Fizz, число:  96
# Число, которое не делится на 3 и на 5 без остатка: 97
# Число, которое не делится на 3 и на 5 без остатка: 98
# Fizz, число:  99
# Buzz, число: 100

# %% [markdown]
# ## Задача 4. Избавляемся от дубликатов.

# %% [markdown]
# **Условие.** В данном упражнении вам предстоит разработать программу, в которой у  пользователя будет запрошен список слов, пока он не оставит строку ввода пустой. После этого на экране должны быть показаны слова, введенные пользователем, но без повторов, – каждое по одному разу. При этом
# слова должны быть отображены в том же порядке, в  каком их вводили с клавиатуры. Например, если пользователь на запрос программы введет следующий список слов:
# ```
# first
# second
# first
# third
# second
# ```
# программа должна вывести:
# ```
# first
# second
# third
# ```

# %%
values = input("Введите ваш список слов. (оставьте пустое значения для завершения): ")
data_list = []
п
i = 0
while values != "":
    data_list.insert(i, values)
    i += 1
    values = input("Введите ваш список слов. (оставьте пустое значения для завершения): ")
set1 = set(data_list)

for i in data_list:
    print(i)

print(" ")
print('\n'.join(sorted(set1,reverse=True)))
# Out:
# Введите ваш список слов. (оставьте пустое значения для завершения): привет
# Введите ваш список слов. (оставьте пустое значения для завершения): пока
# Введите ваш список слов. (оставьте пустое значения для завершения): до свидания
# Введите ваш список слов. (оставьте пустое значения для завершения): пока
# Введите ваш список слов. (оставьте пустое значения для завершения):
# привет
# пока
# до свидания
# пока
#
# привет
# пока
# до свидания

# %% [markdown]
# ## Задача 5. Ниже и выше среднего.

# %% [markdown]
# **Условие.** Напишите программу, которая будет запрашивать у  пользователя числа, пока не будет введена пустая строка. Сначала на экран должно быть выведено среднее значение введенного ряда чисел, после этого друг за другом необходимо вывести список чисел ниже среднего, равных ему (если такие
# найдутся) и выше среднего. Каждый список должен предваряться соответствующим заголовком.

# %%
values = input("Введите ваш список цифр. (оставьте пустое значения для завершения): ")
list_num = []
sum_num = 0

while values != "":
    list_num.append(values)
    if values != "":
        sum_num += int(values)
    values = input("Введите ваш список цифр. (оставьте пустое значения для завершения): ")

avg_num = sum_num / len(list_num)
print("Среднее значение введного вами ряда = ",avg_num)

for value in list_num:
    if avg_num == int(value):
        print("Число равное среднему значению ряда: ",int(value))
    elif avg_num > int(value):
        print("Число меньше среднего значения ряда: ",int(value))
    elif avg_num < int(value):
        print("Число выше среднего значения ряда: ",int(value))
# Out:
# Введите ваш список цифр. (оставьте пустое значения для завершения): 1
# Введите ваш список цифр. (оставьте пустое значения для завершения): 2
# Введите ваш список цифр. (оставьте пустое значения для завершения): 3
# Введите ваш список цифр. (оставьте пустое значения для завершения): 4
# Введите ваш список цифр. (оставьте пустое значения для завершения): 5
# Введите ваш список цифр. (оставьте пустое значения для завершения):
# Среднее значение введного вами ряда =  3.0
# Число меньше среднего значения ряда:  1
# Число меньше среднего значения ряда:  2
# Число равное среднему значению ряда:  3
# Число выше среднего значения ряда:  4
# Число выше среднего значения ряда:  5

# %% [markdown]
# ## Задача 6. Решето Эратосфена.

# %% [markdown]
# **Условие.** Решето Эратосфена – алгоритм, изобретенный более 2000 лет назад и служащий для нахождения всех простых чисел от 2 до некоторого целого числа n. Ваше решение должно начинаться с предложения пользователю ввести число, до которого необходимо вывести простые числа. Описание этого алгоритма приведено ниже.
# ```
# Выписываем все целые числа от 0 до заданной границы
# Вычеркиваем 0 и 1 как непростые числа
# Устанавливаем значение переменной p, равное 2
# Пока p меньше указанного числа, делать
#  Вычеркиваем все числа, кратные p, но не его само
#  Устанавливаем значение p, равное следующему невычеркнутому числу
# Выводим все числа, оставшиеся незачеркнутыми
# ```
#
# Ценность данного алгоритма заключается в том, что на бумаге очень легко вычеркнуть все числа, кратные определенному. Для компьютера это также не самая сложная задача – с этим может прекрасно справиться инструкция for с третьим параметром, переданным функции range. Мы знаем, что вычеркнутые числа на листочке не являются простыми, но физически они никуда с листа не деваются и должны участвовать в дальнейшем алгоритме. Так что и в компьютерной симуляции не стоит «вычеркивать» элемент путем его удаления из списка – вместо этого лучше
# будет присвоить ему значение 0. После завершения алгоритма все ненулевые числа в списке и будут простыми.
# Напишите программу на Python, реализующую указанный выше алгоритм для отображения простых чисел в интервале от двух до значения, введенного пользователем. Если алгоритм будет реализован правильно, ваша программа справится с выводом всех простых чисел от двух до миллиона всего за пару секунд.

# %% [markdown]
# > **Примечание.** Приведенный в данном упражнении алгоритм поиска простых чисел, названный в честь Эратосфена, был далеко не единственным вкладом греческого математика в науку. Ему также приписывают вычисление длины окружности Земли
# и градус наклона ее оси. Кроме того, с 235 г. до н. э. он служил хранителем знаменитой Александрийской библиотеки.

# %%
num = int(input("Введите число для обозначения границы: "))
list_numbers = []
for i in range(2, num + 1):
    list_numbers.append(i)
    for i in list_numbers:
        for value in list_numbers:
            if value % i == 0 and value != i:
                print(value, end=" ")
                list_numbers.remove(value)
# Out:
# Введите число для обозначения границы: 100
# 4 6 8 9 10 12 14 15 16 18 20 21 22 24 25 26 27 28 30 32 33 34 35 36 38 39 40 42 44 45 46 48 49 50 51 52 54 55 56 57 58 60 62 63 64 65 66 68 69 70 72 74 75 76 77 78 80 81 82 84 85 86 87 88 90 91 92 93 94 95 96 98 99 100

# %% [markdown]
# ## Задача 7. Эрудит.

# %% [markdown]
# **Условие.** В известной игре Эрудит (Scrabble) каждой букве соответствует определенное количество очков. Общая сумма очков, которую получает игрок,
# составивший это слово, складывается из очков за каждую букву, входящую
# в его состав. Чем более употребимой является буква в языке, тем меньше
# очков начисляется за ее использование. Напишите программу, рассчитывающую и отображающую количество очков за собранное слово. Создайте словарь для хранения соответствий между буквами и очками и используйте его в своем решении.
# Система очков в игре Эрудит:
#   * 1  - A, E, I, L, N, O, R, S, T и U
#   * 2  - D и G
#   * 3  - B, C, M и P
#   * 4  - F, H, V, W и Y
#   * 5  - K
#   * 8  - J и X
#   * 10 - Q и Z

# %%
constants = {"A": 1,"E": 1,"I": 1,"L": 1,"N": 1,"O": 1,"R": 1,"S": 1,"T": 1,"U": 1,"D": 2,"G": 2,"B": 3,"C": 3,"M": 3,"P": 3,"F": 4,"H": 4,"V": 4,"W": 4,"Y": 4,"K": 5,"J": 8,"X": 8,"Q": 10,"Z": 10}

string = input("Введите слово: ")
total_sum_point = 0
for i in range(0,len(string)):
       total_sum_point += constants[string[i]]

print("Количество очков за введенное слово: ",total_sum_point)
# Out:
# Введите слово: AEZ
# Количество очков за введенное слово:  12
